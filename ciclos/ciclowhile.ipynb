# %%
 #ciclo  7
inicio=int(input("ingrese el valor inicial : "))
fin=int(input("ingrese el valor final : "))
incremento=int(input("ingrese el incremento : "))
for x in range(inicio,fin,incremento):
  print(x)
# Out:
# ingrese el valor inicial2
# ingrese el valor final20
# ingrese el incremento2
# 2
# 4
# 6
# 8
# 10
# 12
# 14
# 16
# 18

# %%
#tabla de multiplicar
mult=0
tabla=int(input("que tabla desea: "))
for x in range(1,11):
  mult = x*tabla
  print(tabla, "x", x,"=",mult)
# Out:
# que tabla desea: 5
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %%
#ciclo while
mult=0
tabla=int(input("que tabla desea"))
x=1
while x<+11:
  mult=tabla* x
  print(tabla, "x",x,"=",mult)
  x=x+1
# Out:
# que tabla desea2
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20

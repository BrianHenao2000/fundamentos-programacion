# %% [markdown]
# Contexto: Parcial primer corte de  Fundamentos de Programacion
# Fecha:22-09-22
# Versión: 1.0
# Autores: Brian Jimenez Henao
# Jeronimo Aristizabal
# Elsa Victoria Alzate

# %%
#ejercicio #1
#ciclo for
numero=int(input("Hasta donde va el ciclo:"))
num1=0
num2=1
res=int
print(num1)
print(num2)
for i in range (numero):
  res=num1+num2
  print(res)
  num1=num2
  num2=res

# %%
#ejercicio #1
#ciclo while
num1=0
num2=1
inicio=input("inicie el ciclo")
final=input("finalice el ciclo")
while (num2<=34):
  print(num2)
  num1,num2=num2,num2+num1

# %%
#ejercicio 2
from itertools import combinations
num=[10,9,8,7,6]
for x in combinations(num,4):
  print(x)

#Nos guiamos de un manual de python para aprender a importar https://docs.python.org/3/reference/import.html y tambien observamos videos

# %%
#ejercicio 3
#sumatoria a
num=int(input("Ingrese num cinco: "))
i = 5
sumatoria =int(0) 
while i <= num:
  sumatoria += 5
  i += 5
  i=i+ 5
print("El valor de la sumatoria es :"+ str(sumatoria))

#sumatoria b
num=int(input("Ingrese num tres: "))
n = 0
sumatoria =int(0) 
while i <= num:
  sumatoria += 0
  n += 0
  n=n+ 0
print("El valor de la sumatoria es :"+ str(sumatoria))

#sumatoria c
num=int(input("Ingrese num tres: "))
i = 1
sumatoria =int(0) 
while i <= num:
  sumatoria += 1
  i += 1
  i=i+ 1
print("El valor de la sumatoria es :"+ str(sumatoria))

# %%
#punto numero 4
#NOMINA

#iiiiii
can_hombres=int(input("Ingrese cantidad de hombres de la empresa : "))
can_mujeres=int(input("Ingrese cantidad de mujeres de la empresa : "))
nombre_trabajador=str(input("ingrese su Nombre: "))
horas_laborales=int(input("ingrese cuantas horas a la semana trabajo: "))
salario_normal=int(input("ingrese valor de su salario mensual: "))
impuesto=int
salario_semanal=int
sueldo_hombres=0
sueldo_mujeres=0
total_h=int(0)
total_m=int(0)
sueldo_total_hym=int(0)
print("ESTE ES EL SUELDO DE LOS EMPLEADOS DE LA EMPRESA")
for x in range(can_hombres,1):
  sueldo_hombres= salario_normal+salario_normal
  print("el sueldo de hombre es" , sueldo_hombres)
total_h=salario_normal*can_hombres
print("el sueldo total de los hombres es : " ,total_h)
#--------------------------------------
print("ESTE ES EL SUELDO DE LAS EMPLEADAS DE LA EMPRESA")
for x in range(can_mujeres,1):
  sueldo_mujeres= salario_normal+salario_normal
  print("El sueldo de las mujeres es: ", sueldo_mujeres)
total_m=salario_normal*can_mujeres
print("El sueldo total de las mujeres es: ", total_m)
#--------------------------------------------
sueldo_total_hym=total_h+total_m
print("El sueldo neto es:" ,sueldo_total_hym)
  
if (horas_laborales>=40):
  horas_extras= (horas_laborales*1.8)
  print(nombre_trabajador,"el valor de sus horas extras es de : " ,horas_extras)
else:
  print(nombre_trabajador,"no tiene horas extras")
if (salario_normal<=1800000):
  print(nombre_trabajador,"su salario esta libre de impuestos")
else:
  (salario_normal>1800000)
  impuesto=(salario_normal*20)/100
  print(nombre_trabajador,"su valor de impuesto es " , impuesto)
if (salario_normal>2300000):
  impuesto=(salario_normal*30)/100
  print(nombre_trabajador,"su valor de impuesto es " , impuesto)
if(salario_normal>0):
  salario_semanal=salario_normal/4
  print(nombre_trabajador , "su salario semanal es : " , salario_semanal)

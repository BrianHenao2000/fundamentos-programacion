# %%
 #importar
 import pandas as pd
 notaSemillero=pd.DataFrame({'Nombres':['pedro','darden','leidy','martha',
                                        'andrea','carlos','felipe','andres','julian'],
                             'nota1':
                             'semestre':[10,9,7,8,10,9,10,8,9],
                             'ciudad':['pasto','manizales','pereira','huila','medellin','bogota','pereira','mariquita','supia']})

print(notaSemillero)

# %%
#programa:calculo del factorial
#declarar variables
num=0
fac=1
#lescturas
num=int(input("Digite un numero"))
#calcular procesos
for i in range(1,num+1):
  fac=fac* i
  print("el factor es",str(fac))

# %%
import math
num= int(input("Digite numero: "))
print("El factorial es :",str(math.factorial(num)))
# Out:
# Digite numero: 5
# El factorial es : 120

# %%
def miFactorial():
 num=0
 fac=1
 #lescturas
 num=int(input("Digite un numero "))
 #calcular procesos
 for i in range(1,num+1):
  fac=fac* i
 print("el factor es",str(fac))
miFactorial()
miFactorial()

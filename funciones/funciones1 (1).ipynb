# %%
#funciones de manejo de cadenas
mensaje1= "hola" + "mundo "
print(len(mensaje1))

nombre= ""
apellido=""
nombreCompleto=""
nombre= input("digite nombre ;")
apellido= input("Digite apellido ")
nombreCompleto=nombre+ ""+apellido
print("su nombre completo es :", nombreCompleto)

# %%
mensaje2= "hola"  * 10
print(mensaje2)
# Out:
# holaholaholaholaholaholaholaholaholahola

# %%
mensaje5 = ascii
ascii=input("Ingrese una palabra")
mensaje5a = mensaje5.find(ascii)
print(mensaje5a)
# Out:
# Ingrese una palabrahola
# -1

# %%
def buscarposCad(texto,buscar):
  pos=texto.find(buscar)
  return pos

textoleer=input("digite cadena origen:")
textoBuscar=input("digite texto a buscar: ")

res = buscarposCad(textoleer,textoBuscar)
print("posicion: " ,str(res))

if res >=0:
  print("posicion : ",str(res))
else:
  print("El texto buscado no existe en la cadena")

# %%
mensaje7= "hola mundo"
mensaje7a= mensaje7.lower()
input()
print(mensaje7a)

# %%
mensaje8= "HOLA-MUNDO mundo"
mensaje8a= mensaje8.replace(" ","MARAVILLOSO")
print(mensaje8a)
# Out:
# HOLA-MUNDOMARAVILLOSOmundo

# %%
mensaje9 ="hola mundo"
mensaje9a =mensaje9[1:8]
mensaje92=input("ingrese un valor")
print(mensaje9a)
# Out:
# ingrese un valorm
# ola mun

# %%
mensaje9="hola mundo"
starloc=2
endloc=8
mensaje9b = mensaje9[startloc:endloc]
print

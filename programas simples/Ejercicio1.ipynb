# %% [markdown]
# DESCRIPCIÓN: Un camión recorre por una carretera a 20mts en 5 segundos,su velocidad es de 25 m/s ¿Cual ha sido su aceleración final?
# Autor: Brian Jimenéz Henao
# Fecha: 10-09-22
# versión:1.0

# %%
#declaracion variables
valorI_int=""
valorF_int=""

resultado_int=""

# %%
#entradas
valorI_int=int(input("Ingrese Velocidad Inicial del camión: "))
valorF_int=int(input("ingrese velocidad Final del camión "))
# Out:
# Ingrese Velocidad Inicial del camión: 50
# ingrese velocidad Final del camión 50

# %%
#procesos
resultado_int= valorI_int-valorF_int / 5

# %%
#salidas
print("La aceleracion final es",resultado_int)
# Out:
# La velocidad final es 40.0

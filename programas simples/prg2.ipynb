# %% [markdown]
# **EJERCICIO 1**
# Dos pueblos que distan 12K/m estan unidos por una carretra recta.-Un ciclista viaja de un pueblo al otro con una velocidad constante de 10m/s-
# Calcular que tiempo emplea.
#
# **NOMBRE DEL PROGRAMA**
# Ejercicio 1
#
# **Autores:**
# Brian Jimenez Henao

# %%
#variables
var_ent_int_estudiante =""
var_ent_int_numeroUno =0
var_ent_int_numeroDos =0
var_pro_int_sumaNumeros =0

# %%
#Lecturas entradas por teclado
var_ent_int_numeroUno = input("Ingrese el nombre del estudiante:")
var_ent_int_numeroUno = int(input("Digite el número uno: "))
var_ent_int_numeroDos = int(input("Digite el número uno: "))
# Out:
# Ingrese el nombre del estudiante:juan
# Digite el número uno: 45
# Digite el número uno: 5

# %%
#salidas - impresiones de resultados 
print("La variable Número uno:",var_ent_int_numeroUno)
print("La variable Número dos:",var_ent_int_numeroDos)
print("La suma de los numeros es:",var_pro_int_sumaNumeros)
# Out:
# La variable Número uno: 45
# La variable Número dos: 5
# La suma de los numeros es: 0

# %%
#procesos
var_pro_int_sumaNumeros = var_ent_int_numeroUno + var_ent_int_numeroDos
